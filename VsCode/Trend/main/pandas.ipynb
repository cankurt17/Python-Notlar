# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('urunler.csv')

# %%
x = np.arange(1,6)
y = np.arange(2,11,2)

# %%
fig = plt.figure(figsize=(6,4))
axes = fig.add_axes([0,0,1,1])
axes.plot(x,x**0.5,color="red",label="Tws")
axes.plot(x,x**2,color="yellow",label="Apple")
axes.plot(x,x**3,color="#4055c2",label="Xiaomi")
axes.legend()
